# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, wordnet
import re, string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.datasets import fetch_20newsgroups

lemmatizer = WordNetLemmatizer()
stopwords = stopwords.words('english')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/josephtanner/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/josephtanner/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = fetch_20newsgroups(remove = ('headers', 'footers', 'qutes'))

# %%
news_df = pd.DataFrame({'Article': data.data})

# %%
news_df.head()
# Out:
#                                              Article
# 0  I was wondering if anyone out there could enli...
# 1  A fair number of brave souls who upgraded thei...
# 2  well folks, my mac plus finally gave up the gh...
# 3  Robert J.C. Kyanko (rob@rjck.UUCP) wrote:\n> a...
# 4  From article <C5owCB.n3p@world.std.com>, by to...

# %%
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {'J': wordnet.ADJ,
                'N': wordnet.NOUN,
                'V': wordnet.VERB,
                'R': wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def cleaner(text):
    text = re.sub('@\S+', '', str(text).lower()) # remove user mentions
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text) # remove punctuation
    text = re.sub(r'http\S+', '', text) # remove http links
    tokens = word_tokenize(text) # tokenize the text
    tokens = [token for token in tokens if not token in stopwords and len(token) > 2]
    words = ' '.join([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in tokens])
    
    return words

# %%
news_df['cleaned_text'] = news_df['Article'].apply(lambda x: cleaner(x))

# %%
news_df.head()
# Out:
#                                              Article  \
# 0  I was wondering if anyone out there could enli...
# 1  A fair number of brave souls who upgraded thei...
# 2  well folks, my mac plus finally gave up the gh...
# 3  Robert J.C. Kyanko (rob@rjck.UUCP) wrote:\n> a...
# 4  From article <C5owCB.n3p@world.std.com>, by to...
#
#                                         cleaned_text
# 0  wonder anyone could enlighten car saw day 2doo...
# 1  fair number brave soul upgraded clock oscillat...
# 2  well folk mac plus finally give ghost weekend ...
# 3  robert kyanko rob write abraxis writes article...
# 4  article c5owcbn3p tombaker tom baker article c...

# %%
news_df.reset_index(inplace=True)

# %%
news_df.rename(columns={'index': 'num'}, inplace=True)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(news_df.cleaned_text)
words = np.array(vectorizer.get_feature_names())

# %%
nmf = NMF(n_components=20, random_state=1, solver='mu')
W = nmf.fit_transform(X)
H = nmf.components_
# Out:
# /Users/josephtanner/opt/anaconda3/envs/chinese_research/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "

# %%
for i, topic in enumerate(H):
    print('Topic {}: {}'.format(i, ', '.join([str(x) for x in words[topic.argsort()[-5:]]])))
# Out:
# Topic 0: get, say, dont, people, one
# Topic 1: do, use, run, program, window
# Topic 2: play, win, player, team, game
# Topic 3: escrow, clipper, encryption, chip, key
# Topic 4: floppy, hard, scsi, disk, drive
# Topic 5: believe, bible, christian, jesus, god
# Topic 6: mail, anyone, email, please, thanks
# Topic 7: palestinian, jew, arab, israeli, israel
# Topic 8: color, monitor, video, driver, card
# Topic 9: mile, price, dealer, engine, car
# Topic 10: turk, turkey, armenia, turkish, armenian
# Topic 11: include, new, price, offer, sale
# Topic 12: firearm, crime, weapon, law, gun
# Topic 13: ftp, directory, image, format, file
# Topic 14: article, orbit, launch, nasa, space
# Topic 15: help, like, anyone, appreciate, would
# Topic 16: value, system, moral, morality, objective
# Topic 17: eat, restaurant, chinese, food, msg
# Topic 18: dog, rider, ride, motorcycle, bike
# Topic 19: port, simms, speed, use, mac

# %%
def topic_table(model, feature_names, n_top_words):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        t = (topic_idx)
        topics[t] = [feature_names[i] for i in top_words(topic, n_top_words)]
    
    return pd.DataFrame(topics)


def top_words(topic, n_top_words):
    return topic.argsort()[:-n_top_words -1:-1]


def whitespace_tokenizer(text):
    pattern = r'(?u)\b\w\w+\b'
    tokenizer_regex = RegexpTokenizer(pattern)
    tokens = tokenizer_regex.tokenize(text)
    
    return tokens

def unique_words(text):
    ulist = []
    [ulist.append(x) for x in text if x not in ulist]
    
    return ulist

# %%
docweights = nmf.transform(vectorizer.transform(news_df.cleaned_text))

# %%
n_top_words = 8

topic_df = topic_table(nmf, words, n_top_words).T

topic_df['topics'] = topic_df.apply(lambda x: [' '.join(x)], axis = 1) # join each word into a list
topic_df['topics'] = topic_df['topics'].str[0] # remove list brackets
topic_df['topics'] = topic_df['topics'].apply(lambda x: whitespace_tokenizer(x)) # tokenize
topic_df['topics'] = topic_df['topics'].apply(lambda x: unique_words(x)) # remove duplicate words
topic_df['topics'] = topic_df['topics'].apply(lambda x: [' '.join(x)]) # rejoin into list
topic_df['topics'] = topic_df['topics'].str[0] # remove list brackets

# %%
topic_df
# Out:
#             0           1           2           3            4            5  \
# 0         one      people        dont         say          get        think
# 1      window     program         run         use           do  application
# 2        game        team      player         win         play       season
# 3         key        chip  encryption     clipper       escrow   government
# 4       drive        disk        scsi        hard       floppy          ide
# 5         god       jesus   christian       bible      believe        faith
# 6      thanks      please       email      anyone         mail         post
# 7      israel     israeli        arab         jew  palestinian     lebanese
# 8        card      driver       video     monitor        color          vga
# 9         car      engine      dealer       price         mile        model
# 10   armenian     turkish     armenia      turkey         turk     genocide
# 11       sale       offer       price         new      include         sell
# 12        gun         law      weapon       crime      firearm     criminal
# 13       file      format       image   directory          ftp          bmp
# 14      space        nasa      launch       orbit      article         moon
# 15      would  appreciate      anyone        like         help      greatly
# 16  objective    morality       moral      system        value        frank
# 17        msg        food     chinese  restaurant          eat       effect
# 18       bike  motorcycle        ride       rider          dog          rid
# 19        mac         use       speed       simms         port         scsi
#
#              6        7                                             topics
# 0       writes  article       one people dont say get think writes article
# 1      problem  manager  window program run use do application problem ...
# 2         year    score        game team player win play season year score
# 3        phone   system  key chip encryption clipper escrow government ...
# 4   controller     boot    drive disk scsi hard floppy ide controller boot
# 5       christ   belief  god jesus christian bible believe faith christ...
# 6      address  advance  thanks please email anyone mail post address a...
# 7      lebanon    state  israel israeli arab jew palestinian lebanese l...
# 8         mode  diamond   card driver video monitor color vga mode diamond
# 9       driver      oil      car engine dealer price mile model driver oil
# 10       azeri   muslim  armenian turkish armenia turkey turk genocide ...
# 11    shipping      use     sale offer price new include sell shipping use
# 12       right    state  gun law weapon crime firearm criminal right state
# 13     program  convert  file format image directory ftp bmp program co...
# 14      writes  shuttle  space nasa launch orbit article moon writes sh...
# 15       could  program  would appreciate anyone like help greatly coul...
# 16     livesey    keith  objective morality moral system value frank li...
# 17       study    cause  msg food chinese restaurant eat effect study c...
# 18      helmet    honda    bike motorcycle ride rider dog rid helmet honda
# 19       modem   memory         mac use speed simms port scsi modem memory

# %%
topic_df = topic_df['topics'].reset_index()

# %%
topic_df.columns = ['topic_num', 'topics']

# %%
topic_df
# Out:
#     topic_num                                             topics
# 0           0       one people dont say get think writes article
# 1           1  window program run use do application problem ...
# 2           2        game team player win play season year score
# 3           3  key chip encryption clipper escrow government ...
# 4           4    drive disk scsi hard floppy ide controller boot
# 5           5  god jesus christian bible believe faith christ...
# 6           6  thanks please email anyone mail post address a...
# 7           7  israel israeli arab jew palestinian lebanese l...
# 8           8   card driver video monitor color vga mode diamond
# 9           9      car engine dealer price mile model driver oil
# 10         10  armenian turkish armenia turkey turk genocide ...
# 11         11     sale offer price new include sell shipping use
# 12         12  gun law weapon crime firearm criminal right state
# 13         13  file format image directory ftp bmp program co...
# 14         14  space nasa launch orbit article moon writes sh...
# 15         15  would appreciate anyone like help greatly coul...
# 16         16  objective morality moral system value frank li...
# 17         17  msg food chinese restaurant eat effect study c...
# 18         18    bike motorcycle ride rider dog rid helmet honda
# 19         19         mac use speed simms port scsi modem memory

# %%
num = news_df['num'].tolist()

# %%
df_temp = pd.DataFrame({'num': num,
                      'topic_num': docweights.argmax(axis=1)})

# %%
merged_topic = df_temp.merge(topic_df, on='topic_num', how='left')

# %%
df_topics = pd.merge(news_df, merged_topic, on='num', how='left')

# %%
df_topics
# Out:
#          num                                            Article  \
# 0          0  I was wondering if anyone out there could enli...
# 1          1  A fair number of brave souls who upgraded thei...
# 2          2  well folks, my mac plus finally gave up the gh...
# 3          3  Robert J.C. Kyanko (rob@rjck.UUCP) wrote:\n> a...
# 4          4  From article <C5owCB.n3p@world.std.com>, by to...
# ...      ...                                                ...
# 11309  11309  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...
# 11310  11310  I have a (very old) Mac 512k and a Mac Plus, b...
# 11311  11311  I just installed a DX2-66 CPU in a clone mothe...
# 11312  11312  In article <1qkgbuINNs9n@shelley.u.washington....
# 11313  11313  Stolen from Pasadena between 4:30 and 6:30 pm ...
#
#                                             cleaned_text  topic_num  \
# 0      wonder anyone could enlighten car saw day 2doo...          9
# 1      fair number brave soul upgraded clock oscillat...          6
# 2      well folk mac plus finally give ghost weekend ...          0
# 3      robert kyanko rob write abraxis writes article...          3
# 4      article c5owcbn3p tombaker tom baker article c...          0
# ...                                                  ...        ...
# 11309  nyeda david nye neurology consultation cheaper...          0
# 11310  old mac 512k mac plus problem screen blank som...          4
# 11311  instal dx266 cpu clone motherboard try mount c...         19
# 11312  article 1qkgbuinns9n bolson edward bolson writ...          0
# 11313  steal pasadena 430 630 415 blue white honda cb...         18
#
#                                                   topics
# 0          car engine dealer price mile model driver oil
# 1      thanks please email anyone mail post address a...
# 2           one people dont say get think writes article
# 3      key chip encryption clipper escrow government ...
# 4           one people dont say get think writes article
# ...                                                  ...
# 11309       one people dont say get think writes article
# 11310    drive disk scsi hard floppy ide controller boot
# 11311         mac use speed simms port scsi modem memory
# 11312       one people dont say get think writes article
# 11313    bike motorcycle ride rider dog rid helmet honda
#
# [11314 rows x 5 columns]

# %%
df_topics.topic_num.value_counts()
# Out:
# 0     1976
# 2     1008
# 6      838
# 11     788
# 5      629
# 1      560
# 19     544
# 14     533
# 15     524
# 12     483
# 3      461
# 9      448
# 8      402
# 18     377
# 13     374
# 4      362
# 7      316
# 17     302
# 16     230
# 10     159
# Name: topic_num, dtype: int64
